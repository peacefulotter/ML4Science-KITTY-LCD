# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline 
# %matplotlib widget

import torch
import numpy as np

from matplotlib import pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from kitti.dataset import KittyDataset

# cannot take less then 2048 -> we want 1024
# take w,h=128 -> we want 64
# => each getitem returns 4 LCD input 
num_pc = 2048
w = 128
h = 128
dataset = KittyDataset(root="./", mode='train', num_pc=num_pc, img_width=w, img_height=h)

# %%
idx = 2
img, pc = dataset[idx]
img.shape, pc.shape
# Out:
# Keeping nb points = 82
# ((320, 1226, 3), (6, 82))

# %%
from matplotlib import cm

fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(img.reshape((w, h, 3))) #, interpolation='nearest'
ax2.scatter(pc[0], pc[1], c=pc[2]) # cmap=cm.coolwarm
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
