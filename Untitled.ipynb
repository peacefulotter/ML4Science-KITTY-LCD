# %%
# %matplotlib inline 

from corri2p.dataset import kitti_pc_img_dataset
from matplotlib import pyplot as plt

# %%
num_pc = 40800
dataset = kitti_pc_img_dataset("./", 'train', num_pc)
# Out:
# 2022-12-01 10:51:37.864 | DEBUG    | corri2p.dataset:make_kitti_dataset:149 - ./sequences/00/img_P2
# 2022-12-01 10:51:37.866 | DEBUG    | corri2p.dataset:make_kitti_dataset:151 - 101
# 2022-12-01 10:51:37.867 | DEBUG    | corri2p.dataset:read_calib_files:26 - seq_folders
# 2022-12-01 10:51:37.867 | DEBUG    | corri2p.dataset:read_calib_files:31 - ./calib/03/calib.txt
# 2022-12-01 10:51:37.868 | DEBUG    | corri2p.dataset:read_calib_files:31 - ./calib/05/calib.txt
# 2022-12-01 10:51:37.869 | DEBUG    | corri2p.dataset:read_calib_files:31 - ./calib/10/calib.txt
# 2022-12-01 10:51:37.870 | DEBUG    | corri2p.dataset:read_calib_files:31 - ./calib/08/calib.txt
# 2022-12-01 10:51:37.872 | DEBUG    | corri2p.dataset:read_calib_files:31 - ./calib/04/calib.txt
# 2022-12-01 10:51:37.874 | DEBUG    | corri2p.dataset:read_calib_files:31 - ./calib/06/calib.txt
# 2022-12-01 10:51:37.875 | DEBUG    | corri2p.dataset:read_calib_files:31 - ./calib/07/calib.txt
# 2022-12-01 10:51:37.876 | DEBUG    | corri2p.dataset:read_calib_files:31 - ./calib/00/calib.txt
# 2022-12-01 10:51:37.879 | DEBUG    | corri2p.dataset:read_calib_files:31 - ./calib/02/calib.txt
# 2022-12-01 10:51:37.881 | DEBUG    | corri2p.dataset:read_calib_files:31 - ./calib/01/calib.txt
# 2022-12-01 10:51:37.883 | DEBUG    | corri2p.dataset:read_calib_files:31 - ./calib/09/calib.txt
# load data complete

# %%
idx = 1
data = dataset[idx]
img, pc = data['img'], data['pc']
img.shape, pc.shape
# Out:
# 2022-12-01 10:51:47.098 | INFO     | corri2p.dataset:__getitem__:257 - img_folder: ./sequences/00/img_P3, pc_folder: ./sequences/00/pc_npy_with_normal
# 2022-12-01 10:51:47.105 | INFO     | corri2p.dataset:__getitem__:260 - img: (320, 1226, 3) data: (7, 121184)
# (torch.Size([3, 160, 512]), torch.Size([3, 40800]))

# %%
plt.imshow(img.reshape((160, 512, 3)), interpolation='nearest')
plt.show()
